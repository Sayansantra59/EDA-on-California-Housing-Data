# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('housing.xlsx')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
#Q1.What is the average median income of the data set and check the distribution of data using appropriate plots.

sns.displot(x='median_income',data=data,color='red')
plt.show()
data['median_income'].mean()
# Out:
# np.float64(3.8706710029069766)

# %%
#Q2.Draw an appropriate plot to see the distribution of housing_median_age

sns.displot(x='housing_median_age',data=data,color='green')
plt.show()

# %%
#Q3.Show with the help of visualization, how median_income and median_house_values are related?
A=data[['median_income','median_house_value']] ## create a new dataframe by selecting 2 coloumns
A
# Out:
#        median_income  median_house_value
# 0             8.3252              452600
# 1             8.3014              358500
# 2             7.2574              352100
# 3             5.6431              341300
# 4             3.8462              342200
# ...              ...                 ...
# 20635         1.5603               78100
# 20636         2.5568               77100
# 20637         1.7000               92300
# 20638         1.8672               84700
# 20639         2.3886               89400
#
# [20640 rows x 2 columns]

# %%
sns.set()

# %%
sns.scatterplot(x='median_house_value',y='median_income',data=A, color='teal')
plt.show()

# %%
A.corr() ## check the corelation value
# Out:
#                     median_income  median_house_value
# median_income            1.000000            0.688075
# median_house_value       0.688075            1.000000

# %%
## the plot indicates approx 68% strength is present in between median income and median house values columns.

# %%
#Q4.Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.

data1=data.dropna()
data1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
# Q5.Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.

data2=data.fillna(data['total_bedrooms'].mean()) ##fillna is filling the missing values with the mean value of the data.
data2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
data['total_bedrooms'].mean()
# Out:
# np.float64(537.8705525375618)

# %%
# Q6. Plot latitude versus longitude.

sns.regplot(x='latitude',y='longitude',data=data,color='blue')
plt.show()

# %%
#Q7.Create a data set for which the ocean_proximity is ‘Near ocean’.

data3=data[data['ocean_proximity']=='NEAR OCEAN']
data3
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %%
data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
#Q8.Find the mean and median of the median income for the data set created in question 7.

data3['median_income'].mean()
# Out:
# np.float64(4.0057848006019565)

# %%
data3['median_income'].median()
# Out:
# 3.64705
